# %%
#explain predictions (for use in web application during possible lnr screen)
from eli5 import show_prediction

show_prediction(bst_3, 
                x_actual.iloc[1], 
                show_feature_values=True)
