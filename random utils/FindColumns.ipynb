# %%
def find_columns(searchColumn, dbaseList):
  #function to find name of databases and tables with column name specified
  #returns all accessible dbase objects in list supplied in call to function.tables.columns with column matching provided column name
  
  #create empty list to dump objects since dataframes are immutible (arrgh)
  dumpList = []
  
  #create list of column names
  outColList = ['dbase','table','column_name','data_type']
  
  #get dbase names  - this is if you wanted to look in all dbases, problem is not all tables are readable and it causes issues down stream...
  #dbases = spark.sql('show databases')
  #countDbases = dbases.count()
  #dbaseList = dbases.take(countDbases)

  #lop thru dbases
  for dbase in dbaseList:
    dbase = str(dbase)
    #dbase = dbase[15:-2]
    
    #get table names
    tables = spark.sql('show tables in ' + dbase + '')
    countTables = tables.count()
    tableList = tables.drop("database", "isTemporary")
    tableList = tableList.take(countTables)

    #loop thru tables
    for table in tableList:
      table = str(table)
      table = table[15:-2]
      
      #get column names
      columns = spark.sql('describe ' + dbase + '.' + table + '')
      countColumns = columns.count()
      columnList = columns.select('col_name')
      datatypeList = columns.select('data_type')
      columnList = columnList.take(countColumns)
      datatypeList = datatypeList.take(countColumns)
      
      #set counter to pull in elements from dataTyepList
      x=0
      
      #loop thru columns
      for colu in columnList:
        colu = str(colu)
        columnName = colu[14:-2]
        if searchColumn.upper() in columnName.upper():
          dtype = datatypeList[x]     
          dumpList.append([dbase,table,columnName,dtype])
        
        x =+ 1
        
    
  #create final dataframe object to return
  returnDataFrame = spark.createDataFrame(dumpList,outColList)   
  return returnDataFrame
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = find_columns('self', ['bronze','silver','customer_centric_silver'])
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dbase</th><th>table</th><th>column_name</th><th>data_type</th></tr></thead><tbody><tr><td>bronze</td><td>umove_contracts</td><td>IsSelfDispatch</td><td>List(bigint)</td></tr><tr><td>bronze</td><td>umove_contracts</td><td>SelfDispatchStatus</td><td>List(bigint)</td></tr><tr><td>bronze</td><td>umove_contracts_historical</td><td>IsSelfDispatch</td><td>List(bigint)</td></tr><tr><td>bronze</td><td>umove_contracts_historical</td><td>SelfDispatchStatus</td><td>List(bigint)</td></tr><tr><td>silver</td><td>customer_rental_summary</td><td>IsSelfDispatch</td><td>List(int)</td></tr><tr><td>silver</td><td>customer_rental_summary</td><td>SelfDispatchStatus</td><td>List(int)</td></tr></tbody></table></div>

# %%
df = find_columns('fee', ['bronze','silver','customer_centric_silver'])
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dbase</th><th>table</th><th>column_name</th><th>data_type</th></tr></thead><tbody><tr><td>bronze</td><td>moving_help_jobs</td><td>ServiceFee</td><td>List(string)</td></tr><tr><td>bronze</td><td>ubox_warehouse_delivery_zones</td><td>WaitTimeFee</td><td>List(int)</td></tr><tr><td>bronze</td><td>umove_contracts</td><td>ContractFees</td><td>List(bigint)</td></tr><tr><td>bronze</td><td>umove_contracts_historical</td><td>ContractFees</td><td>List(bigint)</td></tr><tr><td>bronze</td><td>wss_affiliates</td><td>AllocateFanfFeeByMid</td><td>List(string)</td></tr><tr><td>customer_centric_silver</td><td>moving_help_jobs</td><td>ServiceFee</td><td>List(string)</td></tr></tbody></table></div>

# %%
df = find_columns('damage', ['bronze','silver','customer_centric_silver'])
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dbase</th><th>table</th><th>column_name</th><th>data_type</th></tr></thead><tbody><tr><td>bronze</td><td>corporate_account_details</td><td>AllowCollisionDamage</td><td>List(string)</td></tr><tr><td>bronze</td><td>corporate_account_details</td><td>CollisionDamageAmount</td><td>List(string)</td></tr><tr><td>bronze</td><td>umove_contracts</td><td>EquipmentDamageReports</td><td>List(bigint)</td></tr><tr><td>bronze</td><td>umove_contracts</td><td>QuickClaimDamageEstimates</td><td>List(bigint)</td></tr><tr><td>bronze</td><td>umove_contracts_historical</td><td>EquipmentDamageReports</td><td>List(bigint)</td></tr><tr><td>bronze</td><td>umove_contracts_historical</td><td>QuickClaimDamageEstimates</td><td>List(bigint)</td></tr><tr><td>bronze</td><td>webbest_insert_service_transactions</td><td>QcsDamageEstimateDetails</td><td>List(array<struct<MileageAmount:double,RentalAmount:double,SafeMoveAmount:double,SafeTowAmount:double,MissingDamageCharge:double,FlatTax:double,CleaningFee:double,ProvTax:double,GstTax:double,TnTax:double,Surcharge:double,SuperSafeMoveAmount:double,EnvironmentalFee:double>>)</td></tr></tbody></table></div>

# %%
df = find_columns('edr', ['bronze','silver','customer_centric_silver'])
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dbase</th><th>table</th><th>column_name</th><th>data_type</th></tr></thead><tbody><tr><td>bronze</td><td>contract_service_equipment_transfer</td><td>ExpectedReceiveDate</td><td>List(bigint)</td></tr><tr><td>bronze</td><td>corporate_account_details</td><td>RequestedReservationLimit</td><td>List(string)</td></tr><tr><td>bronze</td><td>customers</td><td>AlternateDrivers</td><td>List(string)</td></tr><tr><td>bronze</td><td>equipment_inventory_snapshot</td><td>ExpectedReceiveDateTime</td><td>List(string)</td></tr><tr><td>bronze</td><td>lnr_history_closed_contracts</td><td>expectedreceivedate</td><td>List(timestamp)</td></tr><tr><td>bronze</td><td>lnr_history_closed_contracts</td><td>CreateDateDriverslicenseinfo</td><td>List(timestamp)</td></tr><tr><td>bronze</td><td>lnr_history_open_contracts</td><td>expectedreceivedate</td><td>List(timestamp)</td></tr><tr><td>bronze</td><td>lnr_history_open_contracts</td><td>CreateDateDriverslicenseinfo</td><td>List(timestamp)</td></tr><tr><td>bronze</td><td>repair_statements</td><td>EdrNumber</td><td>List(string)</td></tr><tr><td>bronze</td><td>umove_contracts</td><td>ExpectedReceiveDate</td><td>List(bigint)</td></tr><tr><td>bronze</td><td>umove_contracts_historical</td><td>ExpectedReceiveDate</td><td>List(bigint)</td></tr><tr><td>bronze</td><td>webbest_insert_service_transactions</td><td>EdrDetails</td><td>List(array<struct<MileageAmount:double,RentalAmount:double,SafeMoveAmount:double,SafeTowAmount:double,MissingDamageCharge:double,FlatTax:double,CleaningFee:double,ProvTax:double,GstTax:double,TnTax:double,Surcharge:double,SuperSafeMoveAmount:double,EnvironmentalFee:double>>)</td></tr><tr><td>bronze</td><td>webbest_product_inventory</td><td>RecommendedReorder</td><td>List(string)</td></tr><tr><td>silver</td><td>cherwell_incident_details</td><td>ExpectedResolution</td><td>List(boolean)</td></tr><tr><td>silver</td><td>combo_single_contract</td><td>RealignedReceiveEntityCode</td><td>List(int)</td></tr><tr><td>silver</td><td>contract_service_equipment_transfer_general</td><td>ExpectedReceiveDate</td><td>List(bigint)</td></tr><tr><td>silver</td><td>csf_rio_pickup_locations</td><td>OrgEntLstModelCodeRecommendedReservationType</td><td>List(string)</td></tr><tr><td>silver</td><td>csf_rio_pickup_locations</td><td>OptEntLstModelCodeRecommendedReservationType</td><td>List(string)</td></tr><tr><td>silver</td><td>csf_rio_pickup_locations</td><td>ResrvEqpModelCodeRecommendedReservationType</td><td>List(string)</td></tr><tr><td>silver</td><td>customer_rental_summary</td><td>RealignedReceiveEntityCode</td><td>List(int)</td></tr><tr><td>silver</td><td>equipment_inventory_snapshot</td><td>ExpectedReceiveDateTime</td><td>List(string)</td></tr><tr><td>silver</td><td>equipment_inventory_updates</td><td>EqpExpectedReceiveDateTime</td><td>List(string)</td></tr><tr><td>silver</td><td>equipment_transaction</td><td>Equipment_ExpectedReceiveDateTime</td><td>List(string)</td></tr><tr><td>silver</td><td>lnr_history</td><td>expectedreceivedate</td><td>List(bigint)</td></tr><tr><td>silver</td><td>lnr_history_closed_contracts</td><td>expectedreceivedate</td><td>List(timestamp)</td></tr><tr><td>silver</td><td>lnr_history_closed_contracts</td><td>CreateDateDriverslicenseinfo</td><td>List(timestamp)</td></tr><tr><td>silver</td><td>repair_statements</td><td>EdrNumber</td><td>List(string)</td></tr><tr><td>silver</td><td>reservations_first_instance</td><td>ExpectedReceiveDate</td><td>List(int)</td></tr><tr><td>silver</td><td>reservations_walkins</td><td>ExpectedReceiveDate</td><td>List(int)</td></tr><tr><td>silver</td><td>uhaul_com_rio_pickup_locations</td><td>OptModelCodeRecommendedReservationType</td><td>List(string)</td></tr><tr><td>silver</td><td>uhaul_com_rio_pickup_locations</td><td>OrgModelCodeRecommendedReservationType</td><td>List(string)</td></tr><tr><td>silver</td><td>uhaul_com_rio_pickup_locations</td>< ...

# %%
df = find_columns('edr', ['bronze_claims','bronze_legacy'])
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dbase</th><th>table</th><th>column_name</th><th>data_type</th></tr></thead><tbody><tr><td>bronze_claims</td><td>claim_details</td><td>FlaggedReasons</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRQualified</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDREquipmentDriver</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDREquipmentProductAllegation</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDROtherVehicleInvolved</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDROtherVehicleResponsible</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRDamageDescription</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRCargoDamage</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRNonCargoDamage</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRCustomerInjuries</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRThirdPartyInjuries</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDREstimateRequired</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDREstimateDate</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRTotalDamageEstimate</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRAdjustedUhaulEstimate</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDREstimateAmount</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRAdjustedInvoiceAmount</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRTotalDamageCharges</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRAmountPaidForDamages</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRQCSAmount</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRQCSDiscountAmount</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRMinimumQCSDueToday</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRQuickClaimAmount</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRQuickClaimPaidInFull</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRCreditAdminInvoiceAmount</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRCreditAdminInvoiceNumber</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRWireTransferNumber</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRTSent</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRDateReceived</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRSafemovePurchased</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRSafemoveExcluded</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRSafemoveVoidReason</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_exposure</td><td>EstimatedRepairCost</td><td>List(bigint)</td></tr><tr><td>bronze_claims</td><td>claim_exposure</td><td>EstimatedRepairTime</td><td>List(bigint)</td></tr><tr><td>bronze_claims</td><td>claim_exposure</td><td>EOHApprovedReleaseEmailSent</td><td>List(bigint)</td></tr><tr><td>bronze_claims</td><td>claim_exposure</td><td>HoldProjectedReleaseDate</td><td>List(bigint)</td></tr><tr><td>bronze_claims</td><td>claim_exposure</td><td>RequestedReleaseDates</td><td>List ...

# %%
df = find_columns('damage', ['bronze_claims','bronze_legacy'])
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dbase</th><th>table</th><th>column_name</th><th>data_type</th></tr></thead><tbody><tr><td>bronze_claims</td><td>claim_details</td><td>PIDamageAllegations</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>CNClaimedDamages</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRDamageDescription</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRCargoDamage</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRNonCargoDamage</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRTotalDamageEstimate</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRTotalDamageCharges</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>EDRAmountPaidForDamages</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>NHTSACauseDamages</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_details</td><td>WaterDamageEmailSent</td><td>List(string)</td></tr><tr><td>bronze_claims</td><td>claim_exposure</td><td>UPDDamages</td><td>List(bigint)</td></tr><tr><td>bronze_claims</td><td>claim_matters</td><td>PunitiveDamagesAlleged</td><td>List(bigint)</td></tr><tr><td>bronze_legacy</td><td>dmlegacyrecords</td><td>Damage_Indicator</td><td>List(string)</td></tr><tr><td>bronze_legacy</td><td>edlegacyrecords</td><td>Damaged_Indicated</td><td>List(string)</td></tr><tr><td>bronze_legacy</td><td>lilegacyrecords</td><td>Damage_Waiver_Amount</td><td>List(string)</td></tr><tr><td>bronze_legacy</td><td>lilegacyrecords</td><td>Damage_Waiver_Indicator</td><td>List(string)</td></tr><tr><td>bronze_legacy</td><td>lolegacyrecords</td><td>Damage_Waiver_Indicator</td><td>List(string)</td></tr><tr><td>bronze_legacy</td><td>ollegacyrecords</td><td>DamageWaiver_Amount</td><td>List(string)</td></tr><tr><td>bronze_legacy</td><td>ollegacyrecords</td><td>DamageWaiver_Indicator</td><td>List(string)</td></tr><tr><td>bronze_legacy</td><td>rdlegacyrecords</td><td>Damaged_Indicator</td><td>List(string)</td></tr></tbody></table></div>
