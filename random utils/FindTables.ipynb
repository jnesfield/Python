# %%
def find_tables(searchTable, dbaseList=None):
  #function to find name of databases and tables with column name specified
  #returns all accessible dbase objects in list supplied in call to function.tables.columns with column matching provided column name
  
  #create empty list to dump objects since dataframes are immutible (arrgh)
  dumpList = []
  
  #create list of column names
  outColList = ['dbase','table']
  
  #check if dbase list supplied
  if dbaseList == None:
    
    #indicator for later
    dbaseNone = 1
    
    #get dbase names
    dbases = spark.sql('show databases')
    countDbases = dbases.count()
    dbaseList = dbases.take(countDbases)
    
  else:
    #indicator for later
    dbaseNone = 0    

  #lop thru dbases
  for dbase in dbaseList:
    dbase = str(dbase)
    if dbaseNone == 1:
      dbase = dbase[18:-2]
    
    #get table names
    tables = spark.sql('show tables in ' + dbase + '')
    countTables = tables.count()
    tableList = tables.drop("database", "isTemporary")
    tableList = tableList.take(countTables)

    #set counter to pull in elements from dataTyepList
    x=0
    
    #loop thru tables
    for table in tableList:
      table = str(table)
      table = table[15:-2]
      if searchTable.upper() in table.upper():
        dumpList.append([dbase,table])
        
      x =+ 1
   
  #create final dataframe object to return
  returnDataFrame = spark.createDataFrame(dumpList,outColList)   
  return returnDataFrame
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#find tables in all dbases
df = find_tables('contract')
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dbase</th><th>table</th></tr></thead><tbody><tr><td>bronze</td><td>comm_platform_correspondence_contract</td></tr><tr><td>bronze</td><td>contract_quotes</td></tr><tr><td>bronze</td><td>contract_service_equipment_transfer</td></tr><tr><td>bronze</td><td>ealert_contract_hits</td></tr><tr><td>bronze</td><td>lnr_history_closed_contracts</td></tr><tr><td>bronze</td><td>lnr_history_open_contracts</td></tr><tr><td>bronze</td><td>retail_contracts</td></tr><tr><td>bronze</td><td>retail_contracts_historical</td></tr><tr><td>bronze</td><td>umove_contracts</td></tr><tr><td>bronze</td><td>umove_contracts_historical</td></tr><tr><td>bronze</td><td>wss_contracts</td></tr><tr><td>bronze_claims</td><td>claim_contract_coverages</td></tr><tr><td>bronze_ea</td><td>contract_first_instance</td></tr><tr><td>bronze_ea</td><td>contract_transactions_new</td></tr><tr><td>bts_dev</td><td>elavonsettlement_bts_contract_date</td></tr><tr><td>bts_dev</td><td>equipment_rental_deposits_charges_contract</td></tr><tr><td>bts_dev</td><td>equipment_rental_deposits_charges_contract_reservation</td></tr><tr><td>bts_dev</td><td>equipment_rental_deposits_summary_contract</td></tr><tr><td>bts_dev</td><td>payment_dashboard_bts_contract_date</td></tr><tr><td>bts_dev</td><td>payments_daily_bts_contract_date</td></tr><tr><td>bts_dev</td><td>transactions_bts_contract_date</td></tr><tr><td>center_dealer_ops_dev</td><td>contracts_share_d11</td></tr><tr><td>center_dealer_ops_dev</td><td>contracts_share_skeleton_d11</td></tr><tr><td>center_dealer_ops_dev</td><td>h3_contracts</td></tr><tr><td>ces</td><td>contract_reservations</td></tr><tr><td>ces_tmp</td><td>contractdispequip</td></tr><tr><td>ces_tmp</td><td>umove_contracts_contact_summarycc</td></tr><tr><td>ces_tmp</td><td>umove_contracts_dispatchedequipment_summary_cc</td></tr><tr><td>ces_tmp</td><td>umove_contracts_receivedequipment_summarycc</td></tr><tr><td>ces_tmp</td><td>umove_contracts_summary_cc</td></tr><tr><td>ces_tmp</td><td>umove_contracts_to_debug</td></tr><tr><td>common</td><td>combosinglecontract</td></tr><tr><td>common</td><td>combosplitcontract</td></tr><tr><td>common</td><td>contractpayment</td></tr><tr><td>contact_center</td><td>umove_contracts_all</td></tr><tr><td>contact_center_dev</td><td>cancelled_contracts</td></tr><tr><td>contact_center_dev</td><td>remade_contracts</td></tr><tr><td>contract_events</td><td>backup_pos_contracts</td></tr><tr><td>contract_events</td><td>contract_events</td></tr><tr><td>contract_events</td><td>contractrentalcharge_events</td></tr><tr><td>contract_events</td><td>contracttransactiontype_events</td></tr><tr><td>copper</td><td>backup_pos_contracts</td></tr><tr><td>copper</td><td>contract_events</td></tr><tr><td>copper</td><td>prev_corp_contract_trans</td></tr><tr><td>copper</td><td>temp_mult_contracts</td></tr><tr><td>copper</td><td>temp_mult_contracts_rectype</td></tr><tr><td>copper</td><td>temp_mult_contracts_upd</td></tr><tr><td>copper</td><td>temp_new_contracts</td></tr><tr><td>copper</td><td>temp_upd_contracts</td></tr><tr><td>customer_centric_model</td><td>contract_cancellation</td></tr><tr><td>customer_centric_model</td><td>umove_contract_charge</td></tr><tr><td>customer_centric_model</td><td>umove_contract_corporate</td></tr><tr><td>customer_centric_model</td><td>umove_contract_customer</td></tr><tr><td>customer_centric_model</td><td>umove_contract_payment</td></tr><tr><td>customer_centric_silver</td><td>contract_cancellation</td></tr><tr><td>customer_centric_silver</td><td>contract_customer_communication</td></tr><tr><td>customer_centric_silver</td><td>umove_contract_charge</td></tr><tr><td>customer_centric_silver</td><td>umove_contract_corporate</td></tr><tr><td>customer_centric_silver</td><td>umove_contract_customer</td></tr><tr><td>customer_centric_silver</td><td>umove_contract_payment</td></tr><tr><td>customer_insights</td><td>contract_customer_comm ...

# %%
#find tables in specified dbases
df = find_tables('entity' , ['bts','bronze','silver'])
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dbase</th><th>table</th></tr></thead><tbody><tr><td>bronze</td><td>entity_exception_hours</td></tr><tr><td>silver</td><td>entity_exception_hours</td></tr><tr><td>silver</td><td>overage_entity_info_current</td></tr></tbody></table></div>

# %%
#find tables in specified dbases
df = find_tables('location' , ['bts','bronze','silver'])
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dbase</th><th>table</th></tr></thead><tbody><tr><td>bronze</td><td>csf_rio_pickup_locations</td></tr><tr><td>bronze</td><td>rio_dropoff_locations</td></tr><tr><td>bronze</td><td>roadside_towing_locations</td></tr><tr><td>bronze</td><td>uhaul_com_rio_pickup_locations</td></tr><tr><td>silver</td><td>csf_rio_pickup_locations</td></tr><tr><td>silver</td><td>rio_dropoff_locations</td></tr><tr><td>silver</td><td>roadside_towing_locations</td></tr><tr><td>silver</td><td>roadside_vendors_vendorlocations</td></tr><tr><td>silver</td><td>uhaul_com_rio_pickup_locations</td></tr></tbody></table></div>
